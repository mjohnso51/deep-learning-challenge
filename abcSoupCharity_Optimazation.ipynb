# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# ...

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'
df = application_df.drop(columns = ['EIN','NAME'])
df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION  STATUS     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  \
# 0   Association       1              0                      N     5000
# 1  Co-operative       1         1-9999                      N   108590
# 2   Association       1              0                      N     5000
# 3         Trust       1    10000-24999                      N     6692
# 4         Trust       1  100000-499999                      N   142590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
# Determine the number of unique values in each column.
df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
count = df['APPLICATION_TYPE'].value_counts()
count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = list(count.iloc[8:].index)
cutoff_value = 528

# Replace in dataframe
for app in application_types_to_replace:
    df['APPLICATION_TYPE'] = df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
count2 = df['CLASSIFICATION'].value_counts()
count2
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
count2 = count2.loc[count2 > 1]
count2
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(count2.iloc[5:].index)
cutoff_value_classifications = 1883

# Replace in dataframe
for cls in classifications_to_replace:
    df['CLASSIFICATION'] = df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2235
# C3000     1918
# C2100     1883
# C1370        1
# C1236        1
# C2190        1
# C4200        1
# C5200        1
# C1248        1
# C2600        1
# C1580        1
# C6100        1
# C1820        1
# C1900        1
# C2570        1
# C1570        1
# C3700        1
# C2500        1
# C1283        1
# C2380        1
# C1732        1
# C1728        1
# C2170        1
# C4120        1
# C8210        1
# C4500        1
# C1245        1
# C2561        1
# C2150        1
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
dummies = pd.get_dummies(df)
dummies.head()
# Out:
#    STATUS  ASK_AMT  IS_SUCCESSFUL  APPLICATION_TYPE_Other  \
# 0       1     5000              1                       0
# 1       1   108590              1                       0
# 2       1     5000              0                       0
# 3       1     6692              1                       0
# 4       1   142590              1                       0
#
#    APPLICATION_TYPE_T10  APPLICATION_TYPE_T19  APPLICATION_TYPE_T3  \
# 0                     1                     0                    0
# 1                     0                     0                    1
# 2                     0                     0                    0
# 3                     0                     0                    1
# 4                     0                     0                    1
#
#    APPLICATION_TYPE_T4  APPLICATION_TYPE_T5  APPLICATION_TYPE_T6  ...  \
# 0                    0                    0                    0  ...
# ...

# %%
# Split our preprocessed data into our features and target arrays
y = dummies['IS_SUCCESSFUL'].values
X = dummies.drop(columns='IS_SUCCESSFUL').values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Attempt 1
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])
hidden_nodes1 = 20
hidden_nodes2 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes1, input_dim = input_features_total, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes2, activation = 'relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 20)                1400
#
#  dense_1 (Dense)             (None, 10)                210
#
#  dense_2 (Dense)             (None, 1)                 11
#
# ...
# Total params: 1621 (6.33 KB)
# Trainable params: 1621 (6.33 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 811us/step - loss: 0.5961 - accuracy: 0.6952
# Epoch 2/100
# 804/804 [==============================] - 1s 907us/step - loss: 0.5590 - accuracy: 0.7270
# Epoch 3/100
# 804/804 [==============================] - 1s 969us/step - loss: 0.5547 - accuracy: 0.7299
# Epoch 4/100
# 804/804 [==============================] - 1s 796us/step - loss: 0.5525 - accuracy: 0.7301
# Epoch 5/100
# 804/804 [==============================] - 1s 769us/step - loss: 0.5509 - accuracy: 0.7307
# Epoch 6/100
# 804/804 [==============================] - 1s 777us/step - loss: 0.5502 - accuracy: 0.7309
# Epoch 7/100
# 804/804 [==============================] - 1s 782us/step - loss: 0.5501 - accuracy: 0.7320
# Epoch 8/100
# 804/804 [==============================] - 1s 815us/step - loss: 0.5487 - accuracy: 0.7315
# Epoch 9/100
# 804/804 [==============================] - 1s 791us/step - loss: 0.5487 - accuracy: 0.7325
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5534 - accuracy: 0.7319 - 277ms/epoch - 1ms/step
# Loss: 0.5533910989761353, Accuracy: 0.7318950295448303

# %%
# Export our model to HDF5 file
filepath = r"C:\Users\cello\Git\deep-learning-challenge\Optimazation1.h5"
nn.save(filepath, save_format='h5')
# Out:
# C:\Users\cello\anaconda3\lib\site-packages\keras\src\engine\training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Attempt 2
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])
hidden_nodes1 = 20
hidden_nodes2 = 10
hidden_nodes3 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes1, input_dim = input_features_total, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes2, activation = 'relu'))

# Third hidden Layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes3, activation = 'relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_3 (Dense)             (None, 20)                1400
#
#  dense_4 (Dense)             (None, 10)                210
#
#  dense_5 (Dense)             (None, 10)                110
#
#  dense_6 (Dense)             (None, 1)                 11
#
# ...
# Total params: 1731 (6.76 KB)
# Trainable params: 1731 (6.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 754us/step - loss: 0.5799 - accuracy: 0.7146
# Epoch 2/100
# 804/804 [==============================] - 1s 745us/step - loss: 0.5578 - accuracy: 0.7265
# Epoch 3/100
# 804/804 [==============================] - 1s 749us/step - loss: 0.5548 - accuracy: 0.7297
# Epoch 4/100
# 804/804 [==============================] - 1s 759us/step - loss: 0.5526 - accuracy: 0.7302
# Epoch 5/100
# 804/804 [==============================] - 1s 761us/step - loss: 0.5515 - accuracy: 0.7308
# Epoch 6/100
# 804/804 [==============================] - 1s 749us/step - loss: 0.5512 - accuracy: 0.7307
# Epoch 7/100
# 804/804 [==============================] - 1s 779us/step - loss: 0.5500 - accuracy: 0.7313
# Epoch 8/100
# 804/804 [==============================] - 1s 872us/step - loss: 0.5494 - accuracy: 0.7313
# Epoch 9/100
# 804/804 [==============================] - 1s 770us/step - loss: 0.5487 - accuracy: 0.7309
# Epoch 10/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5510 - accuracy: 0.7339 - 299ms/epoch - 1ms/step
# Loss: 0.5509799122810364, Accuracy: 0.7338775396347046

# %%
filepath = r"C:\Users\cello\Git\deep-learning-challenge\Optimazation2.h5"
nn.save(filepath, save_format='h5')

# %%
# Attempt 3
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])
hidden_nodes1 = 20
hidden_nodes2 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes1, input_dim = input_features_total, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes2, activation = 'relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_7 (Dense)             (None, 20)                1400
#
#  dense_8 (Dense)             (None, 10)                210
#
#  dense_9 (Dense)             (None, 1)                 11
#
# ...
# Total params: 1621 (6.33 KB)
# Trainable params: 1621 (6.33 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,validation_split=.15,epochs=100)
# Out:
# Epoch 1/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.5983 - accuracy: 0.6994 - val_loss: 0.5718 - val_accuracy: 0.7162
# Epoch 2/100
# 684/684 [==============================] - 1s 1ms/step - loss: 0.5621 - accuracy: 0.7272 - val_loss: 0.5708 - val_accuracy: 0.7204
# Epoch 3/100
# 684/684 [==============================] - 1s 896us/step - loss: 0.5562 - accuracy: 0.7294 - val_loss: 0.5661 - val_accuracy: 0.7191
# Epoch 4/100
# 684/684 [==============================] - 1s 924us/step - loss: 0.5539 - accuracy: 0.7302 - val_loss: 0.5645 - val_accuracy: 0.7199
# Epoch 5/100
# 684/684 [==============================] - 1s 862us/step - loss: 0.5524 - accuracy: 0.7307 - val_loss: 0.5660 - val_accuracy: 0.7196
# Epoch 6/100
# 684/684 [==============================] - 1s 859us/step - loss: 0.5509 - accuracy: 0.7320 - val_loss: 0.5633 - val_accuracy: 0.7201
# Epoch 7/100
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5576 - accuracy: 0.7314 - 167ms/epoch - 623us/step
# Loss: 0.557573139667511, Accuracy: 0.7314285635948181

# %%
filepath = r"C:\Users\cello\Git\deep-learning-challenge\Optimazation3.h5"
nn.save(filepath, save_format='h5')

# %%
# Attempt 4
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_total = len(X_train[0])
hidden_nodes1 = 20
hidden_nodes2 = 10
hidden_nodes3 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes1, input_dim = input_features_total, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes2, activation = 'tanh'))

# Third hidden Layer
nn.add(tf.keras.layers.Dense(units = hidden_nodes3, activation = 'relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units = 1, activation = 'sigmoid'))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_10 (Dense)            (None, 20)                1400
#
#  dense_11 (Dense)            (None, 10)                210
#
#  dense_12 (Dense)            (None, 10)                110
#
#  dense_13 (Dense)            (None, 1)                 11
#
# ...
# Total params: 1731 (6.76 KB)
# Trainable params: 1731 (6.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 1s 971us/step - loss: 0.5917 - accuracy: 0.6941
# Epoch 2/100
# 804/804 [==============================] - 1s 797us/step - loss: 0.5581 - accuracy: 0.7288
# Epoch 3/100
# 804/804 [==============================] - 1s 780us/step - loss: 0.5536 - accuracy: 0.7302
# Epoch 4/100
# 804/804 [==============================] - 1s 779us/step - loss: 0.5513 - accuracy: 0.7314
# Epoch 5/100
# 804/804 [==============================] - 1s 788us/step - loss: 0.5503 - accuracy: 0.7313
# Epoch 6/100
# 804/804 [==============================] - 1s 909us/step - loss: 0.5495 - accuracy: 0.7313
# Epoch 7/100
# 804/804 [==============================] - 1s 782us/step - loss: 0.5490 - accuracy: 0.7320
# Epoch 8/100
# 804/804 [==============================] - 1s 837us/step - loss: 0.5484 - accuracy: 0.7331
# Epoch 9/100
# 804/804 [==============================] - 1s 944us/step - loss: 0.5477 - accuracy: 0.7335
# Epoch 10/100
# ...

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5521 - accuracy: 0.7315 - 262ms/epoch - 979us/step
# Loss: 0.5520650744438171, Accuracy: 0.7315452098846436

# %%
filepath = r"C:\Users\cello\Git\deep-learning-challenge\Optimazation4.h5"
nn.save(filepath, save_format='h5')
